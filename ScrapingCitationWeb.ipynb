# %% [markdown]
# <a href="https://colab.research.google.com/github/MrBrain314/Data-Analysis/blob/main/ScrapingCitationWeb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install html5lib

# %%
#Python program to scrape website
#and save quotes from website
import requests
from bs4 import BeautifulSoup
import csv

# %%
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL)

soup = BeautifulSoup(r.content, 'html5lib')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life
#   </title>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
#   <meta content="pass, it, on, passiton, values, kindness" name="keywords"/>
#   <meta content="The Foundation for a Better Life" name="twitter:site_name"/>
#   <meta content="@passiton_values" name="twitter:site"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Thank you for visiting." name="twitter:description"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" name="twitter:image"/>
# ...

# %%
quotes=[]  # a list to store quotes

table = soup.find('div', attrs = {'id':'all_quotes'})

for row in table.find_all('div',
                         attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(" #")[0]
    quote['author'] = row.img['alt'].split(" #")[1]
    quotes.append(quote)

# %%
quotes
# Out:
# [{'theme': 'INSPIRATION',
#   'url': '/inspirational-quotes/8296-when-we-strive-to-become-better-than-we-are',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8296/medium/20250411_friday_quote.jpg',
#   'lines': 'When we strive to become better than we are, everything around us becomes better, too.',
#   'author': '<Author:0x00007fb3b2341eb8>'},
#  {'theme': 'INSPIRATION',
#   'url': '/inspirational-quotes/8438-inspiration-exists-but-it-has-to-find-us-working',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/8438/medium/20250410_thursday_quote.jpg',
#   'lines': 'Inspiration exists, but it has to find us working.',
#   'author': '<Author:0x00007fb3b235e9c8>'},
#  {'theme': 'INSPIRATION',
#   'url': '/inspirational-quotes/4545-keep-your-face-always-toward-the-sunshine-and',
#   'img': 'https://assets.passiton.com/quotes/quote_artwork/4545/medium/20250409_wednesday_quote.jpg',
# ...

# %%
print(quotes[15])
# Out:
# {'theme': 'CONFIDENCE', 'url': '/inspirational-quotes/6508-confidence-comes-not-from-always-being-right', 'img': 'https://assets.passiton.com/quotes/quote_artwork/6508/medium/20250321_friday_quote.jpg', 'lines': 'Confidence comes not from always being right, but from not fearing to be wrong.', 'author': '<Author:0x00007fb3b2380dc0>'}

# %%
import pandas as pd

df = pd.DataFrame(quotes)

# %%
df.head(10)
# Out:
#          theme                                                url  \
# 0  INSPIRATION  /inspirational-quotes/8296-when-we-strive-to-b...
# 1  INSPIRATION  /inspirational-quotes/8438-inspiration-exists-...
# 2  INSPIRATION  /inspirational-quotes/4545-keep-your-face-alwa...
# 3  INSPIRATION  /inspirational-quotes/7999-light-tomorrow-with...
# 4  INSPIRATION  /inspirational-quotes/7563-learn-from-yesterda...
# 5    CHARACTER  /inspirational-quotes/6995-waste-no-more-time-...
# 6    CHARACTER  /inspirational-quotes/8178-what-we-know-matter...
# 7    CHARACTER  /inspirational-quotes/7290-be-more-concerned-w...
# 8    CHARACTER  /inspirational-quotes/7558-the-truth-of-your-c...
# 9    CHARACTER  /inspirational-quotes/7366-character-may-be-ma...
#
#                                                  img  \
# 0  https://assets.passiton.com/quotes/quote_artwo...
# 1  https://assets.passiton.com/quotes/quote_artwo...
# 2  https://assets.passiton.com/quotes/quote_artwo...
# ...

# %%
# Conversion en fichier CSV

filename = 'Inspirational_quotes.csv'
with open(filename, 'w', newline='') as f:
    w = csv.DictWriter(f,['theme','url','img','lines','author'])
    w.writeheader()
    for quote in quotes:
        w.writerow(quote)

# Egalement de cette maniere

"""
import pandas as pd
df = pd.DataFrame(quotes)
df.to_csv(filename, index=False, encoding='utf-8')

"""
# Out:
# "\nimport pandas as pd\ndf = pd.DataFrame(quotes)\ndf.to_csv(filename, index=False, encoding='utf-8')\n\n"

# %%
df.to_excel ('Inspirational_quotes.xlsx', index=False)
